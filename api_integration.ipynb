# %% [markdown]
# **Prompt Engineering: OpenAI API Key Integration**

# %%
# Install the 0.28.0 version of OpenAI Python library (if not already installed)
# !pip install openai==0.28.0
# Out:
# Collecting openai==0.28.0
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28.0) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28.0) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28.0) (3.11.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.0) (2024.12.14)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.0) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.0) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.0) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.0) (1.18.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->openai==0.28.0) (4.12.2)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.57.4
#     Uninstalling openai-1.57.4:
#       Successfully uninstalled openai-1.57.4
# Successfully installed openai-0.28.0

# %%
# Import the OpenAI library
import openai

# Assign your OpenAI API key
from google.colab import userdata
openai.api_key = userdata.get('openai_api_key')

# Select your required large language model (LLM) from the below set of variables
language_model = "o1"                 # model supports at most 1,00,000 completion tokens
# language_model = "o1-mini"            # model supports at most 65,536 completion tokens
# language_model = "o1-preview"         # model supports at most 32,768 completion tokens

# language_model = "gpt-3.5-turbo"      # model supports at most 4,096 completion tokens
# language_model = "gpt-3.5-turbo-16k"  # model supports at most 16,384 completion tokens

# language_model = "gpt-4-turbo"        # model supports at most 4,096 completion tokens
# language_model = "gpt-4"              # model supports at most 8,192 completion tokens
# language_model = "gpt-4o"             # model supports at most 16,384 completion tokens
# language_model = "gpt-4-32k"          # model supports at most 32,768 completion tokens

# %%
# Define a function to interact with OpenAI's Chat API (LLM supported: o1)
def ask_openai_o1(prompt, model=language_model):
    try:
        response = openai.ChatCompletion.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": prompt},
            ],
            max_completion_tokens=60000  # parameter name compatible for o1 model
        )
        return response.choices[0].message['content'].strip()
    except Exception as e:
        return f"An error occurred: {e}"

# %%
# Define a function to interact with OpenAI's Chat API (LLMs supported: o1-mini, o1-preview)
def ask_openai_o1_series(prompt, model=language_model):
    try:
        response = openai.ChatCompletion.create(
            model=model,
            messages=[
                {
                    "role": "user",
                    "content": (
                        "You are a helpful assistant. "  # Incorporate 'system' role content here
                        + prompt
                    )
                }
            ],
            max_completion_tokens=32000  # parameter name compatible for o1 model
        )
        return response.choices[0].message['content'].strip()
    except Exception as e:
        return f"An error occurred: {e}"

# %%
# Define a function to interact with OpenAI's Chat API (LLMs supported: 3.5+, 4+ and 4o)
def ask_openai_3_and_4_series(prompt, model=language_model):
    try:
        response = openai.ChatCompletion.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": prompt},
            ],
            max_tokens=15000,  # parameter name compatible for 3.5+, 4+ and 4o
            temperature=0.5
        )
        return response.choices[0].message['content'].strip()
    except Exception as e:
        return f"An error occurred: {e}"

# %%
# Simple prompt engineering

"""
Objective: Develop a Python-based solution that automates the process of fetching all Excel files with the same structure
(e.g., identical column names and formats) from a specified folder path. The solution should concatenate these files into a single DataFrame,
preserving the structure and ensuring no data is lost.
"""

prompt = """

Task:
Create a Python script that takes an input folder path containing Excel files with an identical structure and concatenates the data from all the files into one comprehensive DataFrame.
________________________________________
Inputs:
  •	Input Folder Path: The folder containing the Excel files to be processed.
  •	Excel File Structure: All files have the same column names and formats.
Expected Output:
  •	A single consolidated DataFrame containing the combined data from all the Excel files.
________________________________________

Persona:
You are a Python developer specializing in data automation. Your expertise lies in handling structured datasets, writing efficient scripts, and ensuring robustness and scalability.
________________________________________

Format:
Provide the Python script with detailed comments and instructions for execution. Ensure that the script:
  •	Reads all Excel files from the specified folder.
  •	Verifies that all files have the same structure.
  •	Concatenates the files into one DataFrame.
________________________________________
Important Notes:
1.	File Structure Validation:
  •	Ensure all Excel files in the folder have the same column structure; otherwise, concatenation may fail.
2.	Error Handling:
  •	The script must include error messages for missing files, empty folders, and other issues to aid debugging.
3.	Scalability:
  •	Optimize for handling multiple files and large datasets, with options for saving results in different formats.

"""

result = ask_openai_o1(prompt)
print("Response from OpenAI:\n\n", result)
# Out:
# Response from OpenAI:
#
#  #!/usr/bin/env python3
# """
# Script Name: excel_concatenator.py
#
# Description:
#     This script reads all Excel files from a specified folder, verifies that they have the same
#     column structure, and concatenates them into a single pandas DataFrame. The script includes
#     error handling for issues such as:
#         - Invalid folder paths
#         - Empty folders
#         - Mismatched file structures
#         - Large dataset handling
#
# Usage:
#     1. Ensure that Python 3.x is installed on your system.
#     2. Install required packages: pandas and openpyxl (for .xlsx files).
#        Example: pip install pandas openpyxl
#     3. Run the script from a terminal or command prompt:
#        python excel_concatenator.py /path/to/excel/folder
#     4. The script will print out status messages and either:
#        - Display a sample of the combined DataFrame.
#        - Display an error message if an issue occurs.
#        - Optionally save the DataFrame to a CSV or Excel file, if desired (code snippet included but commented).
#
# Notes:
#     - The script assumes all Excel files in the folder have the same columns,
#       in the same order, with the same data types.
#     - This script can be adapted to handle large datasets (e.g., via chunked reading or incremental loading).
# """
#
# import os
# import sys
# import pandas as pd
#
#
# def validate_folder_path(folder_path: str) -> None:
#     """
#     Validate that the folder path exists and is a directory.
#
#     :param folder_path: The path to the folder containing Excel files.
#     :raises FileNotFoundError: If the folder path is invalid or does not exist.
#     """
#     if not os.path.exists(folder_path):
#         raise FileNotFoundError(f"Error: The folder path '{folder_path}' does not exist.")
#     if not os.path.isdir(folder_path):
#         raise NotADirectoryError(f"Error: The path '{folder_path}' is not a directory.")
#
#
# def fetch_excel_files(folder_path: str) -> list:
#     """
#     Retrieve a list of paths of all Excel files in the specified folder.
#
#     :param folder_path: The path to the folder containing Excel files.
#     :return: A list of file paths ending with .xlsx or .xls.
#     """
#     excel_files = []
#     for file_name in os.listdir(folder_path):
#         # Adjust the file extension filters as needed (e.g., for .xlsm)
#         if file_name.lower().endswith((".xlsx", ".xls")):
#             excel_files.append(os.path.join(folder_path, file_name))
#     return excel_files
#
#
# def validate_excel_structure(excel_files: list) -> list:
#     """
#     Read the first Excel file to determine the expected columns, then verify that
#     all subsequent files match this structure.
#
#     :param excel_files: List of Excel file paths.
#     :return: A list of pandas DataFrames.
#     :raises ValueError: If the structure of any file does not match the first file.
#     """
#     dataframes = []
#
#     # Read the first file and store its column structure
#     df_first = pd.read_excel(excel_files[0], engine='openpyxl')
#     expected_columns = list(df_first.columns)
#     dataframes.append(df_first)
#
#     # Validate each subsequent file
#     for file_path in excel_files[1:]:
#         df = pd.read_excel(file_path, engine='openpyxl')
#         current_columns = list(df.columns)
#
#         # Check if columns match (by name and order). If needed, adjust logic for partial matches or ignoring order.
#         if current_columns != expected_columns:
#             raise ValueError(
#                 f"Error: File '{file_path}' does not match the expected structure.\n"
#                 f"Expected columns: {expected_columns}\n"
#                 f"Found columns:    {current_columns}"
#             )
#         dataframes.append(df)
#
#     return dataframes
#
#
# def concatenate_dataframes(dataframes: list) -> pd.DataFrame:
#     """
#     Concatenate multiple DataFrames into a single DataFrame.
#
#     :param dataframes: List of pandas DataFrames.
#     :return: A single concatenated pandas DataFrame.
#     """
#     combined_df = pd.concat(dataframes, ignore_index=True)
#     return combined_df
#
#
# def main(folder_path: str):
#     """
#     Main function to orchestrate reading, validating, and concatenating Excel files from a folder.
#
#     :param folder_path: The path to the folder containing Excel files.
#     """
#     try:
#         # Step 1: Validate folder path
#         validate_folder_path(folder_path)
#
#         # Step 2: Fetch Excel files
#         excel_files = fetch_excel_files(folder_path)
#         if not excel_files:
#             print(f"Error: No Excel files were found in the folder '{folder_path}'.")
#             return
#
#         # Step 3: Validate and create list of DataFrames
#         dataframes = validate_excel_structure(excel_files)
#
#         # Step 4: Concatenate DataFrames
#         combined_df = concatenate_dataframes(dataframes)
#
#         # Display a summary of the combined DataFrame
#         print("Combined DataFrame shape:", combined_df.shape)
#         print("Preview of combined DataFrame (first 5 rows):")
#         print(combined_df.head())
#
#         # Optional: Save combined DataFrame to a CSV file
#         # Uncomment or modify if you need to save the output
#         # output_csv_path = os.path.join(folder_path, "combined_output.csv")
#         # combined_df.to_csv(output_csv_path, index=False)
#         # print(f"DataFrame successfully saved to: {output_csv_path}")
#
#         # Optional: Save combined DataFrame to an Excel file
#         # output_excel_path = os.path.join(folder_path, "combined_output.xlsx")
#         # combined_df.to_excel(output_excel_path, index=False)
#         # print(f"DataFrame successfully saved to: {output_excel_path}")
#
#     except Exception as e:
#         # Catch-all for any errors to aid debugging
#         print(f"An error occurred: {e}")
#
#
# if __name__ == "__main__":
#     # The script can be run via terminal:
#     #   python excel_concatenator.py /path/to/excel/folder
#     # You can also call the main function from another script or environment.
#
#     if len(sys.argv) < 2:
#         print("Usage: python excel_concatenator.py /path/to/excel/folder")
#         sys.exit(1)
#
#     input_folder = sys.argv[1]
#     main(input_folder)
